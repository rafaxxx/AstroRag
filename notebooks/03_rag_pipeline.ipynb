# %%
# !pip install ollama

# %%
import ollama

# %% [markdown]
# # Testando...
#
# ### What are fast radio bursts?

# %%
response = ollama.chat(
    model='mistral',
    messages=[
        {
            'role': 'user',
            'content': 'What are Fast Radio Bursts?'
        }
    ]
)

print(response['message']['content'])
# Out:
#  Fast Radio Bursts (FRBs) are extremely short, bright pulses of radio waves that last only milliseconds and originate from unknown sources far beyond our Milky Way galaxy. The name "Fast" comes from the fact that these bursts have a high dispersion measure, meaning they show a significant change in frequency over time, suggesting they travel through dense interstellar medium.
#
# Despite their discovery in 2007, the source and cause of FRBs remain a mystery. Some theories suggest they might be caused by magnetars (a type of neutron star with extremely powerful magnetic fields), while others propose they could be signals from advanced extraterrestrial civilizations or even collapse events of primordial black holes.
#
# More research is needed to understand these mysterious phenomena better and ultimately determine their true nature.

# %% [markdown]
# ### What is CHIME?

# %%
response = ollama.chat(
    model='mistral',
    messages=[
        {
            'role': 'user',
            'content': 'What is CHIME?'
        }
    ]
)

print(response['message']['content'])
# Out:
#  CHIME (Caltech Submillimeter Observatory) is a radio telescope located at the National Radio Astronomy Observatory's Hat Creek Radio Observatory in California, USA. It was developed by a collaboration between the California Institute of Technology and the National Radio Astronomy Observatory.
#
# CHIME is unique because it uses a technique called fast Fourier Transform (FFT) to process signals from its 1,024 antennas simultaneously, allowing it to scan large areas of the sky quickly and efficiently. It primarily observes the radio waves emitted by hydrogen in the universe, which are particularly useful for studying the early universe and the nature of dark energy.
#
# One of CHIME's most notable discoveries is the detection of fast radio bursts (FRBs), mysterious high-energy signals that last only a few milliseconds but can be incredibly bright. These discoveries have greatly advanced our understanding of the universe and its mysteries.

# %% [markdown]
# ### What frequencies are used in FRB observations?

# %%
response = ollama.chat(
    model='mistral',
    messages=[
        {
            'role': 'user',
            'content': 'What frequencies are used in FRB observations?'
        }
    ]
)

print(response['message']['content'])
# Out:
#  Fast Radio Bursts (FRBs) are highly energetic, millisecond-duration pulses of radio waves that come from unknown sources beyond our Milky Way galaxy. The exact frequencies used to observe FRBs can vary, but they typically fall within the low-frequency range of the radio spectrum.
#
# Most observations have been made in the 1-8 GHz band (this includes the frequency ranges for L-band, C-band, X-band, and Ku-band), although some recent detections have extended to higher frequencies like the S-band (1.2-1.8 GHz) and lower frequencies such as the Low Frequency Array (LOFAR) observations which can extend down to 10 MHz.
#
# The specific frequency used depends on the observatory, its capabilities, and the characteristics of the FRB being studied. For example, some telescopes like LOFAR have excellent sensitivity at lower frequencies, while others, like the Green Bank Telescope (GBT), are better suited for observations in higher frequencies.

# %% [markdown]
# ### How are FRBs distinguished from radio frequency interference?

# %%
response = ollama.chat(
    model='mistral',
    messages=[
        {
            'role': 'user',
            'content': 'How are FRBs distinguished from radio frequency interference?'
        }
    ]
)

print(response['message']['content'])
# Out:
#  Fast Radio Bursts (FRBs) and Radio Frequency Interference (RFI) are both phenomena that can cause sudden, intense radio emissions, but they have distinct differences.
#
# 1. Origin: FRBs are believed to originate from distant galaxies, often billions of light-years away. On the other hand, RFI is typically generated from man-made sources such as satellites, aircraft, power lines, and even microwave ovens or mobile phones.
#
# 2. Duration: FRBs are extremely short, lasting only milliseconds to a few milliseconds, while RFI can last for seconds or even minutes.
#
# 3. Frequency: FRBs span a wide range of radio frequencies, from several hundred MHz to several GHz. RFI is usually confined to specific frequency bands and can be narrowband or broadband.
#
# ...

# %% [markdown]
# ### How can machine learning improve FRB classification?

# %%
response = ollama.chat(
    model='mistral',
    messages=[
        {
            'role': 'user',
            'content': 'How can machine learning improve FRB classification?'
        }
    ]
)

print(response['message']['content'])
# Out:
#  Machine Learning (ML) can significantly enhance Fast Radio Bursts (FRB) classification by helping astronomers identify patterns, categorize bursts, and distinguish between different types of FRBs more efficiently. Here are a few ways ML can be applied:
#
# 1. Automated detection: Machine learning algorithms can be trained to recognize the unique characteristics of FRB signals, allowing for faster and more accurate detection compared to traditional methods that rely on humans visually identifying these bursts.
#
# 2. Classification: ML models can classify FRBs based on their properties, such as duration, polarization, dispersion measure (DM), and fluence. By analyzing large datasets of FRB observations, machine learning algorithms can help astronomers understand the underlying patterns that distinguish between different types of FRBs, like repeaters, one-offs, and other possible subclasses.
#
# ...

# %% [markdown]
# ### What are the challenges of automated FRB detection?

# %%
response = ollama.chat(
    model='mistral',
    messages=[
        {
            'role': 'user',
            'content': 'What are the challenges of automated FRB detection?'
        }
    ]
)

print(response['message']['content'])
# Out:
#  Automated Fast Radio Burst (FRB) detection poses several challenges due to the rare and transient nature of these cosmic phenomena. Here are some key challenges:
#
# 1. Rarity: FRBs are incredibly rare, with only about 50 confirmed detections as of now. This scarcity makes it difficult to gather a large dataset for training machine learning algorithms or creating models for automated detection.
#
# 2. Variability: FRBs show significant variability in their properties such as duration, dispersion measure (DM), fluence, and polarization. This variability can lead to false positives when using automated systems if the system is not designed to handle such variations.
#
# ...

# %% [markdown]
# ### How are convolutional neural networks used in radio astronomy?

# %%
response = ollama.chat(
    model='mistral',
    messages=[
        {
            'role': 'user',
            'content': 'How are convolutional neural networks used in radio astronomy?'
        }
    ]
)

print(response['message']['content'])
# Out:
#  Convolutional Neural Networks (CNNs) have been increasingly used in the field of radio astronomy to analyze and extract valuable information from large datasets generated by radio telescopes. Here's a brief overview of how CNNs are applied:
#
# 1. Image Processing: Radio telescopes produce data that can be represented as images, where each pixel contains intensity values related to radio emissions in the sky at specific frequencies. These images can be treated as 2D or 3D datasets (for time-series observations) and processed with CNNs to identify patterns, structures, and features like galaxies, stars, pulsars, etc.
#
# ...
